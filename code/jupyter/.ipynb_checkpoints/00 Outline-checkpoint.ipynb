# %% [markdown]
# # A Python Quick Start Tutorial - Outline
# ## by Peter Mackenzie-Helnwein
# University of Washington, Seattle, WA
#
# pmackenz@uw.edu
# https://www.ce.washington.edu/facultyfinder/peter-mackenzie-helnwein

# %% [markdown]
# # table of contents
#
# 1. [Basic Concepts](./01%20Basic%20Concepts.ipynb)
#
#    * First step: Hello, World!
#
#    * Creating Variables - no need for a fancy definition :)
#
#    * Structure by indentation
#
#    * Basic Data Types
#
#    * Loops
#
#    * [Exercise 1](./01.1%20Exercise_Functions.ipynb)
#
#
# 2. [Matrix Data Types](./02%20Matrix%20Data%20Types.ipynb)
#
#    * array and matrix classes using numpy
#
#    * Linear algebra in numpy
#
#    * [Exercise 2](./02.1%20Exercise%20numpy.ipynb)
#
#
# 3. [Plotting using matplotlib](./03%20Plotting%20using%20matplotlib.ipynb)
#
#    * 2D plotting
#
#    * [Exercise 3](./03.1%20Exercise%20Plotting.ipynb)
#
#
# 4. [File handling](./04%20File%20handling.ipynb)
#
#    * reading from file
#
#    * writing to a file
#
#    * working with complex file types
#
#    * [Exercise 4](./04.1%20Exercise%20File%20handling.ipynb)
#
#
# 5. [Classes (objects)](./05%20Classes.ipynb)
#
#    * A basic class
#
#    * Inheritance
#
#    * Operator overloading
#
#    * [Exercise 5](./05.1%20Exercise%20Classes.ipynb)
#
#
# 6. [Modules](./06%20Modules.ipynb)
#
#    * Common modules
#
#    * Your functions as modules
#
#    * [Exercise 6](./06.1%20Exercise%20Modules.ipynb)
#
#
# 7. [Machine learning - AI](http://localhost:8889/notebooks/07%20Machine%20Learning%20AI.ipynb)
#
#    * Introduction
#
#    * tensorflow
#
#
# /*
#    * Appendix: Solutions
#
#        * [Solution for Exercise 1](./01.2%20Solution%20of%20Exercise_Functions.ipynb)
#
#        * [Solution for Exercise 2](./02.2%20Solution%20of%20Exercise%20numpy.ipynb)
#
#        * [Solution for Exercise 3](./03.2%20Solution%20of%20Exercise%20Plotting.ipynb)
#
#        * [Solution for Exercise 4](./04.2%20Solution%20of%20Exercise%20File%20handling.ipynb)
#
#        * [Solution for Exercise 5](./05.2%20Solution%20of%20Exercise%20Classes.ipynb)
#
#        * [Solution for Exercise 6](./06.2%20Solution%20of%20Exercise%20Modules.ipynb)
#
# */
